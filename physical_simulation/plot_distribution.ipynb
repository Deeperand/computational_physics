# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import os
os.system('practiec_0306_1.bin')

x = pd.read_csv("practice_0306.txt") 

x_np = x.values
xx = x_np[:,0]
yy = x_np[:,1]

plt.scatter(xx, yy, s=0.3)

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import os
os.system('practiec_0311_2.bin.bin')

x = pd.read_csv("practice_0311_2.txt") 

x_np = x.values
xx = x_np[:,0]
yy = x_np[:,1]

plt.scatter(xx, yy, s=0.3)
